# %%
import pandas as pd

df = pd.read_csv('../datasets/raw/retrosheet-context.csv')

df.head()
# Out:
# /var/folders/np/f11s751j4dj_y_1cj4yxydpwpsr474/T/ipykernel_62019/483841724.py:3: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../datasets/raw/retrosheet-context.csv')
#    eventID        gameID  event_in_game  inning  visitor_or_home  vis_score  \
# 0        0  BLF191404130              1       1                0          0
# 1        1  BLF191404130              2       1                0          0
# 2        2  BLF191404130              3       1                0          0
# 3        3  BLF191404130              4       1                0          0
# 4        4  BLF191404130              5       1                1          0
#
#    home_score  outs runner_1b runner_2b  ... field_2B_playerID  \
# 0           0     0       NaN       NaN  ...          knabo101
# 1           0     0  hanfc101       NaN  ...          knabo101
# 2           0     1       NaN  hanfc101  ...          knabo101
# ...

# %%
df.describe(include='all')
# Out:
#              eventID        gameID  event_in_game        inning  \
# count   1.610758e+07      16107578   1.610758e+07  1.610758e+07
# unique           NaN        182770            NaN           NaN
# top              NaN  NYN197409110            NaN           NaN
# freq             NaN           247            NaN           NaN
# mean    8.053788e+06           NaN   4.559672e+01  5.275960e+00
# std     4.649857e+06           NaN   2.738922e+01  2.714618e+00
# min     0.000000e+00           NaN   1.000000e+00  1.000000e+00
# 25%     4.026894e+06           NaN   2.300000e+01  3.000000e+00
# 50%     8.053788e+06           NaN   4.500000e+01  5.000000e+00
# 75%     1.208068e+07           NaN   6.700000e+01  8.000000e+00
# max     1.610758e+07           NaN   2.470000e+02  2.600000e+01
#
#         visitor_or_home     vis_score    home_score          outs runner_1b  \
# count      1.610758e+07  1.610758e+07  1.610758e+07  1.610758e+07   5275115
# ...

# %%
df.columns
# Out:
# Index(['eventID', 'gameID', 'event_in_game', 'inning', 'visitor_or_home',
#        'vis_score', 'home_score', 'outs', 'runner_1b', 'runner_2b',
#        'runner_3b', 'batterID', 'batter_hand', 'pitch_count', 'pitch_sequence',
#        'play_orig', 'pitcherID', 'pitcher_hand', 'field_C_playerID',
#        'field_1B_playerID', 'field_2B_playerID', 'field_3B_playerID',
#        'field_SS_playerID', 'field_LF_playerID', 'field_CF_playerID',
#        'field_RF_playerID', 'comments', 'theplay', 'sh_flag', 'sf_flag'],
#       dtype='object')
